# %% [markdown]
# 문제 1
# 대륙별 맥주 평균 소비량을 구하라. 5번째로 소비가 많은 대륙의 2번째로 맥주 소비량이 많은 국가의 맥주 소비량을 구하여라
#
# 나의 답변 : 347

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p1_1.csv')
# print(df.head(5))

print(df.groupby('대륙').소비량.mean().sort_values(ascending = False))
#Africa

print(df[df['대륙'] == 'Africa'].groupby('국가명').소비량.sum().sort_values(ascending = False))
#Gabon                       347
# Out:
# 대륙
# Europe           189.409091
# South America    175.083333
# North America    142.277778
# Oceania           89.071429
# Africa            61.750000
# Asia              38.365854
# Name: 소비량, dtype: float64
# 국가명
# Namibia                     376
# Gabon                       347
# South Africa                225
# Angola                      217
# Botswana                    173
# Seychelles                  157
# Cameroon                    147
# Mauritius                    98
# Equatorial Guinea            92
# Swaziland                    90
# Burundi                      88
# Lesotho                      82
# Congo                        76
# Zimbabwe                     64
# Kenya                        58
# Tunisia                      51
# Mozambique                   47
# Uganda                       45
# Rwanda                       43
# Nigeria                      42
# Togo                         36
# Tanzania                     36
# ...

# %% [markdown]
# 문제 2
#
# 총 방문객 수는 관광,방문,유햑연수,취업,기타 방문자 숫자의 합으로 정의한다. 각 국가별 관광 / 총 방문객 수의 비율을 구하고 이를 관광 비율이라 한다. 관광비율이 2번째로 높은 국가의 취업으로 출국한 인원과 관광 숫자가 3번째로 높은 국가의 방문으로 출국한 인원의 합을 구하여라
#
# 나의 답변: 30835

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p1_2.csv')
# print(df.head(5))

df['total'] = df['관광'] + df['방문'] + df['유학연수'] + df['취업']+ df['기타']
# print(df.head(5))
df['ratio'] =  df['관광'] / df['total']

print(df.sort_values('ratio', ascending = False).iloc[1, :])
# 캄보디아   31283.0   1919.0    172.0    22.0   286.0   33682.0  0.928775
# 22

print(df.sort_values('관광', ascending = False).iloc[2, :])
# 30813

print(30813 + 22)
# Out:
# 국가           캄보디아
# 관광        31283.0
# 방문         1919.0
# 유학연수        172.0
# 취업           22.0
# 기타          286.0
# total     33682.0
# ratio    0.928775
# Name: 60, dtype: object
# 국가           태  국
# 관광       416800.0
# 방문        30813.0
# 유학연수       4133.0
# 취업          197.0
# 기타         3111.0
# total    455054.0
# ratio    0.915935
# Name: 29, dtype: object
# 30835

# %% [markdown]
# 문제 3
#
#
# CO(GT),NMHC(GT) 두 컬럼을 min-max normalize를 진행하고 각 컬럼의 모표준편차의 차이의 절댓값을 소숫점 이하 3째 자리까지 구하여라
#
# 못 풀었다

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p1_3.csv')
print(df.head(5))
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5

# %% [markdown]
# 작업 2 유형

# %% [markdown]
# 문제 4

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p2_train2.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p2_test2.csv')

display(train.head(2))
display(test.head(2))

print(train.info())
print(test.info())

train_y = train['Y']
train_x = train.drop(['ID', 'Y'], axis = 1)

test_id = test['ID']
# test_y = test['Y']
test_x = test.drop(['ID'], axis = 1)

x_full = pd.concat([train_x, test_x], axis = 0)
x_full = pd.get_dummies(x_full)

train_x = x_full[:train.shape[0]]
test_x = x_full[train.shape[0]:]

from sklearn.model_selection import train_test_split

trainx, valx, trainy, valy = train_test_split(train_x, train_y, test_size = 0.2)

from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(trainx, trainy)

y_val_pred = model.predict(valx)
from sklearn.metrics import root_mean_squared_error
# import sklearn.metrics

# print(dir(sklearn.metrics))

rmse = root_mean_squared_error(valy,y_val_pred)
print(rmse)

y_pred = model.predict(test_x)
# rmse = root_mean_squared_error(testy,y_pred)

result = pd.DataFrame(y_pred, columns = ['pred'])
result = pd.concat([test_id, result], axis = 1)
result.to_csv('result.csv', index =False)
print(result)
# Out:
#         ID   C1   C2   C3   C4        Date  Weekday  Temperature   Humidity  \
# 0  ID_1300  X_2  Y_0  Z_3  W_2  2023-03-27        0    10.533315  88.101605
# 1  ID_1301  X_0  Y_3  Z_2  W_9  2023-10-12        3    -1.698046  42.811039
#
#    Wind_Speed  Precipitation     Pressure  Visibility   Y
# 0   13.632211       7.814899  1046.992484    6.100292  27
# 1    6.165366       1.139649   985.766276    5.720027  -5
#         ID   C1   C2   C3    C4        Date  Weekday  Temperature   Humidity  \
# 0  ID_4780  X_1  Y_2  Z_2  W_11  2023-07-27        3    28.460744  32.869427
# 1   ID_217  X_2  Y_2  Z_0   W_9  2023-09-05        1    33.699748  20.366573
#
#    Wind_Speed  Precipitation     Pressure  Visibility
# 0   13.978067       1.453519   980.152660    3.091170
# 1    9.032971       1.430375  1014.322511    7.788306
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3934 entries, 0 to 3933
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ...

# %% [markdown]
# 유형 3

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p3_1.csv')
df.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0  0.506278 -0.231322  0.759771 -0.172927 -0.687524 -0.556815 -1.381369
# 1  0.017220  1.530047  0.676838  1.533623 -0.516027  0.949166 -1.180669
# 2  1.436089  0.038078 -0.120501  0.914955 -1.504149  0.443893 -0.696385
# 3 -0.926337 -0.665242 -0.106853 -1.111627 -0.127867  0.746742 -0.345943
# 4 -0.350953 -0.044709 -0.421777  1.359772 -1.619690 -0.645908 -1.717975
#
#          X8        X9       X10       X11       X12       X13       X14  \
# 0  1.633690 -0.869129  0.370614  0.615057 -0.416594 -1.175980  0.113494
# 1  1.895021 -1.211768 -1.081109 -1.067039 -0.611829  0.846854 -0.812381
# 2  0.245013  1.221166 -1.387287 -1.762048 -0.556466  0.130129  0.517210
# 3  0.848144  0.374944 -0.951299  1.097359  0.754369 -0.221183 -0.430509
# 4 -0.598477  1.026014 -0.134644 -0.988988  0.513048 -0.886113  0.247288
#
#         X15  Y
# 0 -0.539230  1
# 1  0.823546  0
# 2  1.056730  0
# 3  0.756875  1
# 4 -0.016664  0

# %% [markdown]
# 유형 3 - 1
# y컬럼을 종속변수로하는 로지스틱회귀 모형을 만들 떄 유의미하지 않은 변수의 개수는? % 상수항은 추가하여 모델링하라
#
# 나의답변: 12

# %% [markdown]
# 유형 3- 2 유의한 변수들 만으로 다시 모델링을 해서 X를 포함하는 독립변수들의 회귀계수 합계를 소숫점 이하 3째 자리까지 구하여라
#
# 나의 답변: 5.610

# %% [markdown]
# 3-2번의 모델 결과에 대해 X뒤의 숫자가 가장 낮은 컬럼이 5단위 늘어나면 오즈비 몇 배로 변화?
#
# 나의 답변: 2.8781250000000003

# %%
from statsmodels.formula.api import logit

formula = "Y ~ X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 + X10 + X11 + X12 + X13 + X14 + X15 "
model = logit(formula, data = df).fit()
print(model.summary())
#pvalues

print(model.pvalues < 0.05)

#3 / 7 8 11

formula2 = "Y ~ X7 + X8 + X11 "
model2 = logit(formula2, data = df).fit()
print(model2.summary())

print(round(5.9960+0.7529+-1.1389 , 4))
#5.61
import numpy as np
print(round(np.exp(model.params['X12']), 3) / round(np.exp(model2.params['X7']), 3))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.060586
#          Iterations 10
#                            Logit Regression Results
# ...
# Dep. Variable:                      Y   No. Observations:                 2500
# Model:                          Logit   Df Residuals:                     2484
# Method:                           MLE   Df Model:                           15
# Date:                Sun, 15 Jun 2025   Pseudo R-squ.:                  0.9126
# Time:                        10:19:36   Log-Likelihood:                -151.47
# converged:                       True   LL-Null:                       -1732.9
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.1997      0.566     -3.883      0.000      -3.310      -1.089
# ...

# %% [markdown]
# 유형 3-4 PIQ를 예측하는 다중선형회귀 모형을 만들고 Brain의 회귀 계수를 구하여라
#
# 나의 답변: 2.0604

# %% [markdown]
# 유형 3-5 모델의 r2를 구하여라
#
# 나의 답변: 0.295

# %% [markdown]
# 유형 3-6 위에서 계산한 모델을 이용하여 뇌크기 90 키 70 몸무게 150일 때 지능을 예측하라
#
# 나의답변: 105.635569

# %%
import pandas as pd
df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e8_p3_2.csv')
df.head()
# Out:
#    PIQ   Brain  Height  Weight
# 0  124   81.69    64.5     118
# 1  150  103.84    73.3     143
# 2  128   96.54    68.8     172
# 3  134   95.15    65.0     147
# 4  110   92.88    69.0     146

# %%
from statsmodels.formula.api import ols

formula = "PIQ ~ Brain + Height+ Weight"

model = ols(formula, data = df).fit()
print(model.summary())

#2.0604
#0.295

train_x = [[90,70,150]]
train_x = pd.DataFrame(train_x, columns = ['Brain','Height', 'Weight'])
y_pred = model.predict(train_x)

print(y_pred)

#105.635569
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    PIQ   R-squared:                       0.295
# Model:                            OLS   Adj. R-squared:                  0.233
# Method:                 Least Squares   F-statistic:                     4.741
# Date:                Sun, 15 Jun 2025   Prob (F-statistic):            0.00722
# Time:                        10:14:24   Log-Likelihood:                -165.25
# No. Observations:                  38   AIC:                             338.5
# Df Residuals:                      34   BIC:                             345.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    111.3536     62.971      1.768      0.086     -16.619     239.326
# ...
